# %% [markdown]
# # QM/MM simulation: VQE within a Polarizable Embedded Framework.
#
# In this tutorial, we will discuss a hybrid quantum-classical algorithm called PE-VQE-SCF introduced in this [paper](https://arxiv.org/pdf/2312.01926). The PE-VQE-scf approch combines:
#
# - Variational Quantum Eigensolver (VQE) – a quantum algorithm for finding ground-state energies of molecules.
# - Self-Consistent Field (SCF) – a classical iterative method used in quantum chemistry.
# - Polarizable Embedding (PE) – a technique to model the effect of an environment (like a solvent or protein) on a quantum system.
#
# The goal is to simulate chemical systems on quantum computers by embedding them in a polarizable environment.
#
# ## Key concepts:
#
# 1- Variational Quantum Eigensolver (VQE)
# - A quantum algorithm that estimates the ground state energy of a molecule.
# - It uses a parameterized quantum circuit (ansatz) and a classical optimizer to minimize the energy expectation value.
# - In this tutorial, we employ VQE with UCCSD ansatz for the quantum part. However, user should be able to replace the VQE and the ansatz with other quantum algorithm.
#
# 2- Self-Consistent Field (SCF)
# - A method where the solution (e.g., molecular orbitals) is updated iteratively until convergence.
# - In this context, SCF is used to update the embedding potential based on the quantum system's density.
#
# 3- Polarizable Embedding (PE)
# - Models the environment as a set of polarizable sites that respond to the quantum system's electric field.
# - The environment affects the quantum system, and vice versa, requiring mutual polarization.
#
# ## PE-VQE-SCF Algorithm Steps
# <div>
# <img src="images/QM-MM-PE.png" width="600">
# </div>
#
# ### Step 1: Initialize
# - Define the quantum region (e.g., a molecule) and the classical environment (e.g., solvent).
# - Set up the PE parameters (multipoles, polarizabilities).
#
# ### Step 2: Build the Hamiltonian
# - Construct the PE-augmented Hamiltonian that includes the molecular Hamiltonian and the interaction with the polarizable environment.
#
# ### Step 3: Run VQE
# - Use a quantum computer (or simulator) to estimate the ground state energy of the system using VQE.
# - The quantum circuit prepares a trial wavefunction, and the classical optimizer adjusts parameters to minimize energy.
#
# ### Step 4: Update Environment
# - Compute the electronic density from the VQE result.
# - Update the induced dipoles in the environment based on this density.
#
# ### Step 5: Self-Consistency Loop
# - Repeat Steps 2–4 until the energy and density converge (i.e., SCF convergence).

# %% [markdown]
# ### Requirments:

# %%
# %pip install cppe
# You might need to install (apt-get update & apt-get install build-essential -y 
#                         apt-get install python3-dev) before installing cppe.
# %pip install pyscf

# %%
from pyscf import gto, scf, solvent
import scipy
import numpy as np
from functools import reduce

import cudaq

cudaq.set_target("nvidia", options='fp64')

# %% [markdown]
# ### Example 1: LiH with 2 water molecules.

# %% [markdown]
# #### Initialize and build the hamiltonian.

# %%
from qchem.classical_pyscf import get_mol_pe_hamiltonian

geometry = 'Li 0.3925 0.0 0.0; H -1.1774 0.0 0.0'
water_pot= "qchem/4NP_in_water.pot"

molecular_data=get_mol_pe_hamiltonian(xyz=geometry, potfile=water_pot, spin=0, charge=0, basis='sto3g', ccsd=True, verbose=True)

obi_mol = molecular_data[0]
tbi_mol = molecular_data[1]
e_nn = molecular_data[2]
obi_pe = molecular_data[3]
nelectrons = molecular_data[4]
norbitals = molecular_data[5]

qubits_num = 2 * norbitals
# Out:
# overwrite output file: Li 0-pyscf.log
# [Pyscf] Total number of electrons =  4
# [Pyscf] Total number of orbitals =  6
# [Pyscf] Total HF energy with solvent: -7.862708330327405
# [Pyscf] Polarizable embedding energy from HF:  -1.112738935888032e-05
# [Pyscf] Total CCSD energy with solvent:  -7.8826805046326065
# [Pyscf] Polarizable embedding energy from CCSD:  -1.0898134919284447e-05
#         Running solver for induced moments.
# 0        --- Norm: 0.000095985493
# 1        --- Norm: 0.000001267579
#         --- Turning on DIIS. ---
# 2        --- Norm: 0.000000012453
# 3        --- Norm: 0.000000000001

# %%
from qchem.hamiltonian import jordan_wigner_fermion, jordan_wigner_pe

spin_mol_ham=jordan_wigner_fermion(obi_mol, tbi_mol, e_nn, tolerance = 1e-12)

spin_pe_ham=jordan_wigner_pe(obi_pe, tolerance = 1e-12)

# %%
mol = gto.M(
    atom = geometry,
    spin = 0,
    charge = 0,
    basis = 'sto3g'
)

mf = scf.RHF(mol)
mf_pe = solvent.PE(mf, water_pot).run()
# Out:
# converged SCF energy = -7.8627083303274

# %% [markdown]
# ### VQE, update environment, and scf loop.

# %%
from qchem.uccsd import uccsd_parameter_size
from qchem.uccsd_vqe import uccsd_circuit_vqe
from qchem.particle_operator import one_particle_op
from qchem.PEoperator import pe_operator
from qchem.uccsd_init_param import get_parameters

e_last = 0.0
conv_tol = 1e-7
dE = 1.0
cycle = 1

# Get the number of parameters
singles, doubles, total = uccsd_parameter_size(nelectrons, qubits_num, spin_mult = 0)
print(f"Number of parameters: {singles} singles, {doubles} doubles, {total} total")

# Get the initial parameters for the UCCSD circuit
theta = get_parameters(xyz=geometry, spin=0, charge=0, basis='sto3g', ccsd=True, without_solvent=False, potfile=water_pot)

#theta = np.zeros(total, dtype=np.float64)


while dE > conv_tol:
#for i in range (2):
    spin_ham = spin_mol_ham + spin_pe_ham
    
    vqe_result = uccsd_circuit_vqe(spin_mult = 0, only_singles = False, only_doubles = False, qubits_num = qubits_num, 
                                   electron_count = nelectrons, optimize = True, theta = theta, 
                                   hamiltonian = spin_ham, method = 'L-BFGS-B', verbose = False)
    
    print(f"VQE Energy: {vqe_result[0]}")
    #print(f"VQE parameters: {vqe_result[1]}")
    print(f"VQE converged: {vqe_result[2]}")
    
    
    theta = vqe_result[1]
    
    if vqe_result[2]:

        # Compute rdm in atomic orbital.
        dm_a = np.zeros((qubits_num // 2, qubits_num // 2))
        dm_b = np.zeros((qubits_num // 2, qubits_num // 2))
            
        n_spatial_orbitals = qubits_num // 2
            
        n_occupied = nelectrons // 2
        n_virtual = n_spatial_orbitals - n_occupied

        alpha_indices = [i * 2 for i in range(n_occupied)]
        alpha_indices += [i * 2 + nelectrons for i in range(n_virtual)]

        beta_indices = [i * 2 + 1 for i in range(n_occupied)]
        beta_indices += [i * 2 + 1 + nelectrons for i in range(n_virtual)]
        
        for i in range(len(alpha_indices)):
            p = alpha_indices[i]
            for j in range(len(alpha_indices)):
                q = alpha_indices[j]
                    
                qubit_op_dm = one_particle_op(p, q)
                result = uccsd_circuit_vqe(spin_mult = 0, only_singles = False, only_doubles = False, qubits_num = qubits_num, 
                                   electron_count = nelectrons, optimize = False, theta = theta, 
                                   hamiltonian = qubit_op_dm, verbose = False)
                dm_a[i, j] = result[0]
                #dm_a[i, j] = cudaq.observe(main_kernel,qubit_op_dm,spin,nelectrons,init_params).expectation()
                
        for i in range(len(beta_indices)):
            p = beta_indices[i]
            for j in range(len(beta_indices)):
                q = beta_indices[j]
                    
                qubit_op_dm = one_particle_op(p, q)
                result = uccsd_circuit_vqe(spin_mult = 0, only_singles = False, only_doubles = False, qubits_num = qubits_num, 
                                   electron_count = nelectrons, optimize = False, theta = theta, 
                                   hamiltonian = qubit_op_dm, verbose = False)
                dm_b[i, j] = result[0]
                #dm_b[i,j]=cudaq.observe(main_kernel,qubit_op_dm,spin,nelectrons,init_params).expectation()

        dm_ao = dm_a + dm_b
        dm_ao = reduce(np.dot, (mf_pe.mo_coeff, dm_ao, mf_pe.mo_coeff.T))
        
        spin_pe_ham, E_pe, V_pe= pe_operator(dm_ao, mol, mf_pe.mo_coeff, water_pot, tolerance = 1e-12)

        result = uccsd_circuit_vqe(spin_mult = 0, only_singles = False, only_doubles = False, qubits_num = qubits_num, 
                                   electron_count = nelectrons, optimize = False, theta = theta, 
                                   hamiltonian = spin_pe_ham, verbose = False)
        edup = result[0]
        #edup=cudaq.observe(main_kernel,spin_pe_ham, spin, nelectrons, init_params).expectation()

        # Check energy are the same
        ovlp = mol.intor_symmetric('int1e_ovlp')
        dm = np.einsum('pi,pq,qj->ij', ovlp, dm_ao, ovlp)
        dm_mo = reduce(np.dot, (mf_pe.mo_coeff.T, dm, mf_pe.mo_coeff))
        edup_np = np.einsum('ij,ji->', V_pe, dm_mo)
        print('Energy from observe call= {:15g} & Energy from np einsum= {:15g}' .format(edup, edup_np), flush=True)

        e_current = vqe_result[0] - edup + E_pe
        dE = np.abs(e_current - e_last)
        e_last = e_current

        print('Cycle {:d}  E_tot = {:.15g}  dE = {:g}' .format(cycle, e_last, dE), flush=True)
        print('Polarizable embedding energy: ', E_pe, flush=True)
        print('Expectation value of polarizable operator: ', edup, flush=True)
        print('\n')

        cycle+=1
    else:
        #raise ValueError("Unsuccessful optimization.")
        print("Unsuccessful optimization. Restart the optimization.", flush=True)
        
        pass
                
        
# Compute the RDM in molecular orbitals.

ovlp = mol.intor_symmetric('int1e_ovlp')
dm = np.einsum('pi,pq,qj->ij', ovlp, dm_ao, ovlp)
dm_mo = reduce(np.dot, (mf_pe.mo_coeff.T, dm, mf_pe.mo_coeff))
noon, U = np.linalg.eigh(dm_mo)
noon = np.flip(noon)
  
print('\n')
print('Final result: ')
print('Polarizable embedding energy: ', E_pe)
print('Expectation value of polarizable operator: ', edup, flush=True)
print('PE-VQE-UCCSD energy (L-BFGS-B)= ', e_last)
print('Natural orbitals occupation number: ', noon)
# Out:
# Number of parameters: 16 singles, 76 doubles, 92 total
# overwrite output file: Li 0-pyscf.log
# Optimizer exited successfully:  True
# VQE Energy: -7.862653947748448
# VQE converged: True
#         Running solver for induced moments.
# 0        --- Norm: 0.000095845584
# 1        --- Norm: 0.000001197558
#         --- Turning on DIIS. ---
# 2        --- Norm: 0.000000011797
# 3        --- Norm: 0.000000000000
# Energy from observe call=     0.000762103 & Energy from np einsum=     0.000762172
# Cycle 1  E_tot = -7.86342685770245  dE = 7.86343
# Polarizable embedding energy:  -1.0807287283488838e-05
# Expectation value of polarizable operator:  0.0007621026667153627
#
#
# Optimizer exited successfully:  True
# VQE Energy: -7.864929437876645
# VQE converged: True
#         Running solver for induced moments.
# 0        --- Norm: 0.000095579045
# 1        --- Norm: 0.000000912891
#         --- Turning on DIIS. ---
# 2        --- Norm: 0.000000005673
# Energy from observe call=     0.000762127 & Energy from np einsum=     0.000762289
# Cycle 2  E_tot = -7.86570224997715  dE = 0.00227539
# Polarizable embedding energy:  -1.0685570031117112e-05
# Expectation value of polarizable operator:  0.0007621265304773657
#
#
# Optimizer exited successfully:  True
# VQE Energy: -7.867127151403674
# VQE converged: True
#         Running solver for induced moments.
# 0        --- Norm: 0.000095474224
# 1        --- Norm: 0.000001032585
#         --- Turning on DIIS. ---
# 2        --- Norm: 0.000000005324
# Energy from observe call=      0.00076207 & Energy from np einsum=     0.000762509
# Cycle 3  E_tot = -7.86789967734613  dE = 0.00219743
# Polarizable embedding energy:  -1.045569882629073e-05
# Expectation value of polarizable operator:  0.0007620702436344786
#
#
# Optimizer exited successfully:  True
# VQE Energy: -7.867135028821157
# VQE converged: True
#         Running solver for induced moments.
# 0        --- Norm: 0.000095456456
# 1        --- Norm: 0.000000959750
#         --- Turning on DIIS. ---
# 2        --- Norm: 0.000000003477
# Energy from observe call=     0.000762071 & Energy from np einsum=      0.00076251
# Cycle 4  E_tot = -7.86790755488102  dE = 7.87753e-06
# Polarizable embedding energy:  -1.0454873774104598e-05
# Expectation value of polarizable operator:  0.0007620711860860143
#
#
# Optimizer exited successfully:  True
# VQE Energy: -7.874861629603537
# VQE converged: True
#         Running solver for induced moments.
# 0        --- Norm: 0.000095504335
# 1        --- Norm: 0.000000869197
#         --- Turning on DIIS. ---
# 2        --- Norm: 0.000000007969
# Energy from observe call=      0.00076193 & Energy from np einsum=     0.000762289
# Cycle 5  E_tot = -7.87563424665248  dE = 0.00772669
# Polarizable embedding energy:  -1.0686648249205582e-05
# Expectation value of polarizable operator:  0.0007619304006912269
#
#
# Optimizer exited successfully:  True
# VQE Energy: -7.875649448712722
# VQE converged: True
#         Running solver for induced moments.
# 0        --- Norm: 0.000095688094
# 1        --- Norm: 0.000000998687
#         --- Turning on DIIS. ---
# 2        --- Norm: 0.000000006661
# Energy from observe call=     0.000761998 & Energy from np einsum=     0.000762239
# Cycle 6  E_tot = -7.87642218438229  dE = 0.000787938
# Polarizable embedding energy:  -1.0737936519111388e-05
# Expectation value of polarizable operator:  0.0007619977330496006
#
#
# Optimizer exited successfully:  True
# VQE Energy: -7.875683737579989
# VQE converged: True
#         Running solver for induced moments.
# 0        --- Norm: 0.000095538931
# 1        --- Norm: 0.000000953521
#         --- Turning on DIIS. ---
# 2        --- Norm: 0.000000007825
# Energy from observe call=     0.000761996 & Energy from np einsum=     0.000762239
# Cycle 7  E_tot = -7.87645647215785  dE = 3.42878e-05
# Polarizable embedding energy:  -1.0738255623923504e-05
# Expectation value of polarizable operator:  0.0007619963222366737
#
#
# Optimizer exited successfully:  True
# VQE Energy: -7.876735424073501
# VQE converged: True
#         Running solver for induced moments.
# 0        --- Norm: 0.000095433881
# 1        --- Norm: 0.000000928885
#         --- Turning on DIIS. ---
# 2        --- Norm: 0.000000011213
# 3        --- Norm: 0.000000000142
# Energy from observe call=     0.000761946 & Energy from np einsum=     0.000762136
# Cycle 8  E_tot = -7.87750821620536  dE = 0.00105174
# Polarizable embedding energy:  -1.0846233649905988e-05
# Expectation value of polarizable operator:  0.0007619458982090273
#
#
# Optimizer exited successfully:  True
# VQE Energy: -7.878768315114468
# VQE converged: True
#         Running solver for induced moments.
# 0        --- Norm: 0.000095519650
# 1        --- Norm: 0.000000930576
#         --- Turning on DIIS. ---
# 2        --- Norm: 0.000000006016
# Energy from observe call=     0.000761926 & Energy from np einsum=     0.000762136
# Cycle 9  E_tot = -7.87954108758264  dE = 0.00203287
# Polarizable embedding energy:  -1.0846874910887126e-05
# Expectation value of polarizable operator:  0.0007619255932574102
#
#
# Optimizer exited successfully:  True
# VQE Energy: -7.87877965818889
# VQE converged: True
#         Running solver for induced moments.
# 0        --- Norm: 0.000095753878
# 1        --- Norm: 0.000001138519
#         --- Turning on DIIS. ---
# 2        --- Norm: 0.000000014302
# 3        --- Norm: 0.000000000126
# Energy from observe call=     0.000761927 & Energy from np einsum=     0.000762137
# Cycle 10  E_tot = -7.87955243063944  dE = 1.13431e-05
# Polarizable embedding energy:  -1.0845748755964318e-05
# Expectation value of polarizable operator:  0.0007619267017986116
#
#
# Optimizer exited successfully:  True
# VQE Energy: -7.87902556210446
# VQE converged: True
#         Running solver for induced moments.
# 0        --- Norm: 0.000095497092
# 1        --- Norm: 0.000000847211
#         --- Turning on DIIS. ---
# 2        --- Norm: 0.000000005428
# Energy from observe call=     0.000761895 & Energy from np einsum=     0.000762132
# Cycle 11  E_tot = -7.87979830924711  dE = 0.000245879
# Polarizable embedding energy:  -1.0852292083502737e-05
# Expectation value of polarizable operator:  0.0007618948505654348
#
#
# Optimizer exited successfully:  True
# VQE Energy: -7.879448899635463
# VQE converged: True
#         Running solver for induced moments.
# 0        --- Norm: 0.000095477450
# 1        --- Norm: 0.000000870759
#         --- Turning on DIIS. ---
# 2        --- Norm: 0.000000004310
# Energy from observe call=     0.000761895 & Energy from np einsum=      0.00076216
# Cycle 12  E_tot = -7.88022161646677  dE = 0.000423307
# Polarizable embedding energy:  -1.0822305876106759e-05
# Expectation value of polarizable operator:  0.0007618945254288077
#
#
# Optimizer exited successfully:  True
# VQE Energy: -7.879448958386103
# VQE converged: True
#         Running solver for induced moments.
# 0        --- Norm: 0.000095616482
# 1        --- Norm: 0.000000926794
#         --- Turning on DIIS. ---
# 2        --- Norm: 0.000000007995
# Energy from observe call=     0.000761895 & Energy from np einsum=      0.00076216
# Cycle 13  E_tot = -7.88022167516918  dE = 5.87024e-08
# Polarizable embedding energy:  -1.0822277095222536e-05
# Expectation value of polarizable operator:  0.0007618945059774677
#
#
#
#
# Final result:
# Polarizable embedding energy:  -1.0822277095222536e-05
# Expectation value of polarizable operator:  0.0007618945059774677
# PE-VQE-UCCSD energy (L-BFGS-B)=  -7.880221675169175
# Natural orbitals occupation number:  [ 1.99946381e+00  1.95677162e+00  3.71329518e-02  4.23171829e-03
#   2.56413954e-03 -1.31182519e-04]

# %% [markdown]
# ### Example 2: NH3 with 46 water molecule using active space.

# %%
from qchem.classical_pyscf import get_mol_pe_hamiltonian
from qchem.hamiltonian import jordan_wigner_fermion, jordan_wigner_pe


geometry_NH3 = 'qchem/NH3.xyz'
water_pot = 'qchem/46_water.pot'


molecular_data=get_mol_pe_hamiltonian(xyz=geometry_NH3, potfile=water_pot, spin=0, charge=0, basis='631g', \
                                  nele_cas=6, norb_cas=6, ccsd=True, verbose=True)

obi_mol = molecular_data[0]
tbi_mol = molecular_data[1]
e_core = molecular_data[2]
obi_pe  =molecular_data[3]
nelectrons = molecular_data[4]
norbitals = molecular_data[5]

qubits_num = 2 * norbitals


spin_mol_ham = jordan_wigner_fermion(obi_mol, tbi_mol, e_core, tolerance = 1e-12)
spin_pe_ham = jordan_wigner_pe(obi_pe, tolerance = 1e-12)
# Out:
# overwrite output file: qchem/NH3-pyscf.log
# [Pyscf] Total number of electrons =  10
# [Pyscf] Total number of orbitals =  15
# [Pyscf] Total HF energy with solvent: -56.46054414611145
# [Pyscf] Polarizable embedding energy from HF:  -0.29872973974625083
# [pyscf] CCSD energy of the active space (using molecular orbitals) with solvent=  -56.470234103882596
# [Pyscf] Polarizable embedding energy from CCSD:  -0.298636870942031
#         Running solver for induced moments.
# 0        --- Norm: 0.569415061548
# 1        --- Norm: 0.189294489021
#         --- Turning on DIIS. ---
# 2        --- Norm: 0.071185464835
# 3        --- Norm: 0.011909162954
# 4        --- Norm: 0.002508657794
# 5        --- Norm: 0.000560416902
# 6        --- Norm: 0.000168379662
# 7        --- Norm: 0.000031770706
# 8        --- Norm: 0.000007648068
# 9        --- Norm: 0.000002512912
# 10        --- Norm: 0.000000797522
# 11        --- Norm: 0.000000158107
# 12        --- Norm: 0.000000030634
# 13        --- Norm: 0.000000005983

# %%
from pyscf import gto, scf, mcscf, solvent

mol = gto.M(
    atom = geometry_NH3,
    spin = 0,
    charge = 0,
    basis = '631g'
)
mf_pe = scf.RHF(mol)
mf_pe = solvent.PE(mf_pe, water_pot).run()
mc = mcscf.CASCI(mf_pe, norbitals, nelectrons)
# Out:
# converged SCF energy = -56.460544146128

# %%
import numpy as np
from functools import reduce
from qchem.uccsd import uccsd_parameter_size
from qchem.uccsd_vqe import uccsd_circuit_vqe
from qchem.particle_operator import one_particle_op
from qchem.PEoperator import pe_operator_as
from qchem.uccsd_init_param import get_parameters

# Get the number of parameters
singles, doubles, total = uccsd_parameter_size(nelectrons, qubits_num, spin_mult = 0)
print(f"Number of parameters: {singles} singles, {doubles} doubles, {total} total")

#theta = get_parameters(xyz = geometry_NH3, spin = 0,charge = 0, basis = '631g', nele_cas = 6, norb_cas = 6, \
#                           ccsd = True, without_solvent = False, potfile = water_pot)
theta = np.zeros(total, dtype=np.float64)

e_last = 0.0
conv_tol = 5e-6
dE = 1.0
cycle = 1

while dE > conv_tol:
#for i in range (1):
    spin_ham = spin_mol_ham + spin_pe_ham
    
    vqe_result = uccsd_circuit_vqe(spin_mult = 0, only_singles = False, only_doubles = False, qubits_num = qubits_num, 
                                   electron_count = nelectrons, optimize = True, theta = theta, 
                                   hamiltonian = spin_ham, method = 'L-BFGS-B', verbose = False)
    print(f"VQE Energy: {vqe_result[0]}")
    #print(f"VQE parameters: {vqe_result[1]}")
    print(f"VQE converged: {vqe_result[2]}")
    
    theta = vqe_result[1]
    
    if vqe_result[2]:

        dm_a = np.zeros((qubits_num // 2, qubits_num // 2))
        dm_b = np.zeros((qubits_num // 2, qubits_num // 2))
        dm = np.zeros((qubits_num, qubits_num))

        n_spatial_orbitals = qubits_num // 2
    
        n_occupied = nelectrons // 2
        n_virtual = n_spatial_orbitals - n_occupied

        alpha_indices = [i * 2 for i in range(n_occupied)]
        alpha_indices += [i * 2 + nelectrons for i in range(n_virtual)]

        beta_indices = [i * 2 + 1 for i in range(n_occupied)]
        beta_indices += [i * 2 + 1 + nelectrons for i in range(n_virtual)]
        
        for i in range(len(alpha_indices)):
            p = alpha_indices[i]
            for j in range(len(alpha_indices)):
                q = alpha_indices[j]
                    
                qubit_op_dm = one_particle_op(p, q)
                result = uccsd_circuit_vqe(spin_mult = 0, only_singles = False, only_doubles = False, qubits_num = qubits_num, 
                                   electron_count = nelectrons, optimize = False, theta = theta, 
                                   hamiltonian = qubit_op_dm, verbose = False)
                dm_a[i, j] = result[0]
                #dm_a[i, j] = cudaq.observe(main_kernel,qubit_op_dm,spin,nelectrons,init_params).expectation()
                
        for i in range(len(beta_indices)):
            p = beta_indices[i]
            for j in range(len(beta_indices)):
                q = beta_indices[j]
                    
                qubit_op_dm = one_particle_op(p, q)
                result = uccsd_circuit_vqe(spin_mult = 0, only_singles = False, only_doubles = False, qubits_num = qubits_num, 
                                   electron_count = nelectrons, optimize = False, theta = theta, 
                                   hamiltonian = qubit_op_dm, verbose = False)
                dm_b[i, j] = result[0]
                #dm_b[i,j]=cudaq.observe(main_kernel,qubit_op_dm,spin,nelectrons,init_params).expectation()

        mocore = mf_pe.mo_coeff[:, :mc.ncore]
        dm_core = np.dot(mocore, mocore.conj().T) * 2
        casdm = dm_a + dm_b
        mocas = mf_pe.mo_coeff[:, mc.ncore:mc.ncore + mc.ncas]
        
        # RDM in atomic orbitals
        dm = dm_core + reduce(np.dot, (mocas, casdm, mocas.conj().T))

        
        spin_pe_hamiltonian, E_pe, V_pe, V_pe_cas= pe_operator_as(dm,mol,mf_pe.mo_coeff,water_pot,mc, tolerance = 1e-12)

        result = uccsd_circuit_vqe(spin_mult = 0, only_singles = False, only_doubles = False, qubits_num = qubits_num, 
                                   electron_count = nelectrons, optimize = False, theta = theta, 
                                   hamiltonian = spin_pe_ham, verbose = False)
        edup = result[0]
        #edup=cudaq.observe(main_kernel,spin_pe_ham, spin, nelectrons, init_params).expectation()


        e_current = vqe_result[0] - edup + E_pe
        dE = np.abs(e_current - e_last)
        e_last = e_current

        print('Cycle {:d}  E_tot = {:.15g}  dE = {:g}' .format(cycle, e_last, dE), flush=True)
        print('Polarizable embedding energy: ', E_pe, flush=True)
        print('Expectation value of polarizable operator: ', edup, flush=True)
        print('\n')

        cycle+=1
    else:
        #raise ValueError("Unsuccessful optimization.")
        print("Unsuccessful optimization. Restart the optimization.", flush=True)
        
        pass
            

# convert dm from ao to mo (D_MO= C.T S D_AO S C )
ovlp = mol.intor_symmetric('int1e_ovlp')
dm = np.einsum('pi,pq,qj->ij', ovlp, dm, ovlp)
dm_mo = reduce(np.dot, (mf_pe.mo_coeff.T, dm, mf_pe.mo_coeff))
noon, U = np.linalg.eigh(dm_mo)
noon = np.flip(noon)
  
print('\n')
print('Final result: ')
print('Polarizable embedding energy: ', E_pe)
print('Expectation value of polarizable operator: ', edup, flush=True)
print('PE-VQE-UCCSD energy (L-BFGS-B)= ', e_last)
print('Natural orbitals occupation number: ', noon)
# Out:
# Number of parameters: 18 singles, 99 doubles, 117 total
# Optimizer exited successfully:  True
# VQE Energy: -56.075107637434485
# VQE converged: True
#         Running solver for induced moments.
# 0        --- Norm: 0.591378169419
# 1        --- Norm: 0.177987901327
#         --- Turning on DIIS. ---
# 2        --- Norm: 0.063383592007
# 3        --- Norm: 0.010768146988
# 4        --- Norm: 0.003791904064
# 5        --- Norm: 0.000645543570
# 6        --- Norm: 0.000149480829
# 7        --- Norm: 0.000045639510
# 8        --- Norm: 0.000011593823
# 9        --- Norm: 0.000003190528
# 10        --- Norm: 0.000000992319
# 11        --- Norm: 0.000000192786
# 12        --- Norm: 0.000000075088
# 13        --- Norm: 0.000000011616
# 14        --- Norm: 0.000000000228
# Cycle 1  E_tot = -56.4706312530156  dE = 56.4706
# Polarizable embedding energy:  -0.2987130428196992
# Expectation value of polarizable operator:  0.09681057276140427
#
#
# Optimizer exited successfully:  True
# VQE Energy: -56.075142606896456
# VQE converged: True
#         Running solver for induced moments.
# 0        --- Norm: 0.555189158464
# 1        --- Norm: 0.198236828946
#         --- Turning on DIIS. ---
# 2        --- Norm: 0.079403331244
# 3        --- Norm: 0.012060687983
# 4        --- Norm: 0.003853532369
# 5        --- Norm: 0.001057673942
# 6        --- Norm: 0.000356131239
# 7        --- Norm: 0.000063092296
# 8        --- Norm: 0.000015352100
# 9        --- Norm: 0.000002867548
# 10        --- Norm: 0.000000690634
# 11        --- Norm: 0.000000166450
# 12        --- Norm: 0.000000051938
# 13        --- Norm: 0.000000010240
# 14        --- Norm: 0.000000002640
# Cycle 2  E_tot = -56.4706662185172  dE = 3.49655e-05
# Polarizable embedding energy:  -0.29871298187913453
# Expectation value of polarizable operator:  0.09681062974157903
#
#
# Optimizer exited successfully:  True
# VQE Energy: -56.07514260692387
# VQE converged: True
#         Running solver for induced moments.
# 0        --- Norm: 0.561754967674
# 1        --- Norm: 0.192677880550
#         --- Turning on DIIS. ---
# 2        --- Norm: 0.080282490263
# 3        --- Norm: 0.013489210094
# 4        --- Norm: 0.008352236349
# 5        --- Norm: 0.001519125657
# 6        --- Norm: 0.000741575002
# 7        --- Norm: 0.000167059015
# 8        --- Norm: 0.000054484930
# 9        --- Norm: 0.000011050548
# 10        --- Norm: 0.000004463885
# 11        --- Norm: 0.000000765547
# 12        --- Norm: 0.000000213823
# 13        --- Norm: 0.000000055561
# 14        --- Norm: 0.000000013240
# 15        --- Norm: 0.000000002160
# Cycle 3  E_tot = -56.4706662185167  dE = 4.76064e-13
# Polarizable embedding energy:  -0.29871298185118117
# Expectation value of polarizable operator:  0.09681062974164294
#
#
#
#
# Final result:
# Polarizable embedding energy:  -0.29871298185118117
# Expectation value of polarizable operator:  0.09681062974164294
# PE-VQE-UCCSD energy (L-BFGS-B)=  -56.47066621851669
# Natural orbitals occupation number:  [ 2.00000000e+00  2.00000000e+00  1.99936633e+00  1.99542183e+00
#   1.99508504e+00  4.74936077e-03  4.37017500e-03  1.08026783e-03
#   1.47490591e-14  1.55380322e-15  1.09783330e-15  9.95737718e-16
#  -1.65899752e-15 -2.78061430e-15 -7.65804072e-15]
